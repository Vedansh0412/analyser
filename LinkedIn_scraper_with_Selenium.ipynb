# %%
import time
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import warnings
warnings.filterwarnings('ignore')

# %%
user_input_job_title = input('Enter Job Titles (with comma separated):').split()
print(user_input_job_title)
# Out:
# ['business', 'development']

# %%
b = []
for i in user_input_job_title:
    x = i.split()
    y = '%20'.join(x)
    b.append(y)

job_title = '%2C%20'.join(b)
print(job_title)
# Out:
# business%2C%20development

# %%
link = f"https://in.linkedin.com/jobs/search?keywords={job_title}&location=India&locationId=&geoId=102713980&f_TPR=r604800&position=1&pageNum=0"
print(link)
# Out:
# https://in.linkedin.com/jobs/search?keywords=business%2C%20development&location=India&locationId=&geoId=102713980&f_TPR=r604800&position=1&pageNum=0

# %%
driver = webdriver.Chrome()
driver.maximize_window()

driver.get(link)
driver.implicitly_wait(10)

# %%
for i in range(0,2):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

    try:
        x = driver.find_element(by=By.CSS_SELECTOR, value="button[aria-label='See more jobs']").click()
        time.sleep(3)
    except:
        pass

# %%
company_name = []

try:
    company = driver.find_elements(by=By.CSS_SELECTOR, value='h4[class="base-search-card__subtitle"]')
    for i in company:
        company_name.append(i.text)

except:
    pass

print(company_name)
# Out:
# ['MakeMyTrip', 'Netflix', 'Unacademy', 'Britannia Industries Limited', 'Freshworks', 'Google', 'Pidilite Industries Limited', 'Freshworks', 'Unacademy', 'Unacademy', 'Ferrero', 'Unacademy', 'Unacademy', 'Jio', 'Aditya Birla Capital', 'Aditya Birla Capital', 'Aditya Birla Capital', 'Freshworks', 'Schbang', 'Amazon', 'NABA Nuova Accademia di Belle Arti', 'Rolls-Royce', 'Infosys', 'Freshworks', 'Freshworks']

# %%
job_title = []

try:
    title = driver.find_elements(by=By.CSS_SELECTOR, value='h3[class="base-search-card__title"]')
    for i in title:
        job_title.append(i.text)

except:
    pass

print(job_title)
# Out:
# ['Business Development Manager - Nashik', 'Manager, Marketing Partnerships - India', 'Business Development Executive', 'Area Sales Executive', 'Business Development Manager - MENA', 'Associate Product Marketing Manager', 'Business Development Executive', 'Business Development Executive', 'Business Development Executive', 'Business Development Executive', 'Business Development Officer Pune', 'Business Development Executive', 'Business Development Executive', 'Area Business Head', 'Business Development Manager (BDM)', 'Business Development Manager (BDM)', 'Business Development Manager (BDM)', 'Senior Business Development Manager - ANZ', 'Business Development Executive', 'Business Development Manager-GlobalSellingIN, NSR, Global sales', 'Sales Advisor India', 'Business Analyst- Service Now', 'Analyst - Business Consulting (Retail)', 'Business Development Manager - NA', 'Business Development Executive - Inside sales (North America)']

# %%
company_location = []

try:
    location = driver.find_elements(by=By.CSS_SELECTOR, value='span[class="job-search-card__location"]')
    for i in location:
        company_location.append(i.text)

except:
    pass

print(company_location)
# Out:
# ['Nashik, Maharashtra, India', 'Mumbai Metropolitan Region', 'Bengaluru, Karnataka, India', 'Parbhani, Maharashtra, India', 'Bengaluru, Karnataka, India', 'Gurgaon, Haryana, India', 'Muzaffarpur, Bihar, India', 'Chennai, Tamil Nadu, India', 'Bangalore Urban, Karnataka, India', 'Bengaluru, Karnataka, India', 'Pune, Maharashtra, India', 'Delhi, India', 'Delhi, India', 'Shillong, Meghalaya, India', 'Ahmedabad, Gujarat, India', 'Chennai, Tamil Nadu, India', 'Cuttack, Odisha, India', 'Bengaluru, Karnataka, India', 'Mumbai, Maharashtra, India', 'Bengaluru, Karnataka, India', 'Mumbai, Maharashtra, India', 'Bengaluru, Karnataka, India', 'Bengaluru East, Karnataka, India', 'Chennai, Tamil Nadu, India', 'Chennai, Tamil Nadu, India']

# %%
job_url = []

try:
    url = driver.find_elements(by=By.XPATH, value='//a[contains(@href, "/jobs/")]')
    for i in url:
        job_url.append(i.get_attribute('href'))

except:
    pass

print(job_url)
# Out:
# ['https://in.linkedin.com/jobs/view/business-development-manager-nashik-at-makemytrip-3841514822?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=LlB1mnPpq58jris2kkEMEA%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/manager-marketing-partnerships-india-at-netflix-3822583007?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=Ga%2BgSEFtuYMgyteTOHXiYg%3D%3D&position=2&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3821021443?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=YrHr7ImE24xi5bJlHCrhCw%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/area-sales-executive-at-britannia-industries-limited-3835907264?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=mfQ0JjVI7rP7AOVgmKk6kQ%3D%3D&position=4&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-manager-mena-at-freshworks-3825476563?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=2RGD%2B1cE6k%2FhHYa8aleuvQ%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/associate-product-marketing-manager-at-google-3824262703?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=YrHDraUi2jTEvUFl%2B%2Feniw%3D%3D&position=6&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-executive-at-pidilite-industries-limited-3840007419?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=IOYVh30RXAQwZnfimsFayA%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-executive-at-freshworks-3825477572?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=I4Ia64vLHhiaseg068X%2B7g%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3835910631?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=3Dp9K%2Btg19WZQ5W5JJdMjg%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3835914425?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=joD8k1jkVPcAgHtYlrY8Xw%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-officer-pune-at-ferrero-3841601092?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=TRR6NkNqCsIm8TbLoKJ8zQ%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3837573106?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=9JyusVqgPVr0%2F%2Fv2w7wssQ%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3840102403?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=S77xg%2B%2FDKzNglVvHoOM2%2FA%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/area-business-head-at-jio-3837545081?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=htfk8TiT3clCZg6roJlyXQ%3D%3D&position=14&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-manager-bdm-at-aditya-birla-capital-3845144166?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=%2FNPTyH4OmwQbCpzp1Mldsw%3D%3D&position=15&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-manager-bdm-at-aditya-birla-capital-3845140511?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=1QQBD7n%2Bq6mx%2B8hZf1wJmg%3D%3D&position=16&pageNum=0&trk=public_jobs_jserp-result_search-card', 'https://in.linkedin.com/jobs/view/business-development-manager-bdm-at-aditya-birla-capital-3845142302?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=UavTNpeJaVI7sdVKQ8h3vw%3D%3D&position=17&pageNum=0&trk=public_jobs_jserp-result_search-card', 'h ...

# %%
print(len(company_name))
print(len(job_title))
print(len(company_location))
print(len(job_url))
# Out:
# 25
# 25
# 25
# 25

# %%
df = pd.DataFrame(company_name, columns=['Company Name'])
df['Job Title'] = pd.DataFrame(job_title)
df['Location'] = pd.DataFrame(company_location)
df['Website URL'] = pd.DataFrame(job_url)
df
# Out:
#                           Company Name  \
# 0                           MakeMyTrip
# 1                              Netflix
# 2                            Unacademy
# 3         Britannia Industries Limited
# 4                           Freshworks
# 5                               Google
# 6          Pidilite Industries Limited
# 7                           Freshworks
# 8                            Unacademy
# 9                            Unacademy
# 10                             Ferrero
# 11                           Unacademy
# 12                           Unacademy
# 13                                 Jio
# 14                Aditya Birla Capital
# 15                Aditya Birla Capital
# 16                Aditya Birla Capital
# 17                          Freshworks
# 18                             Schbang
# 19                              Amazon
# 20  NABA Nuova Accademia di Belle Arti
# 21                         Rolls-Royce
# 22                             Infosys
# 23                          Freshworks
# 24                          Freshworks
#
#                                             Job Title  \
# 0               Business Development Manager - Nashik
# 1             Manager, Marketing Partnerships - India
# 2                      Business Development Executive
# 3                                Area Sales Executive
# 4                 Business Development Manager - MENA
# 5                 Associate Product Marketing Manager
# 6                      Business Development Executive
# 7                      Business Development Executive
# 8                      Business Development Executive
# 9                      Business Development Executive
# 10                  Business Development Officer Pune
# 11                     Business Development Executive
# 12                     Business Development Executive
# 13                                 Area Business Head
# 14                 Business Development Manager (BDM)
# 15                 Business Development Manager (BDM)
# 16                 Business Development Manager (BDM)
# 17          Senior Business Development Manager - ANZ
# 18                     Business Development Executive
# 19  Business Development Manager-GlobalSellingIN, ...
# 20                                Sales Advisor India
# 21                      Business Analyst- Service Now
# 22             Analyst - Business Consulting (Retail)
# 23                  Business Development Manager - NA
# 24  Business Development Executive - Inside sales ...
#
#                              Location  \
# 0          Nashik, Maharashtra, India
# 1          Mumbai Metropolitan Region
# 2         Bengaluru, Karnataka, India
# 3        Parbhani, Maharashtra, India
# 4         Bengaluru, Karnataka, India
# 5             Gurgaon, Haryana, India
# 6           Muzaffarpur, Bihar, India
# 7          Chennai, Tamil Nadu, India
# 8   Bangalore Urban, Karnataka, India
# 9         Bengaluru, Karnataka, India
# 10           Pune, Maharashtra, India
# 11                       Delhi, India
# 12                       Delhi, India
# 13         Shillong, Meghalaya, India
# 14          Ahmedabad, Gujarat, India
# 15         Chennai, Tamil Nadu, India
# 16             Cuttack, Odisha, India
# 17        Bengaluru, Karnataka, India
# 18         Mumbai, Maharashtra, India
# 19        Bengaluru, Karnataka, India
# 20         Mumbai, Maharashtra, India
# 21        Bengaluru, Karnataka, India
# 22   Bengaluru East, Karnataka, India
# 23         Chennai, Tamil Nadu, India
# 24         Chennai, Tamil Nadu, India
#
#                                           Website URL
# 0   https://in.linkedin.com/jobs/view/business-dev...
# 1   https://in.linkedin.com/jobs/view/manager-mark...
# 2   https://in.linkedin.com/jobs/view/business-dev...
# 3   https://in.linkedin.com/jobs/view/area-sales-e...
# 4   https://in.linkedin.com/jobs/view/business-dev...
# 5   https://in.linkedin.com/jobs/view/associate-pr...
# 6   https://in.linkedin.com/jobs/view/business-dev...
# 7   https://in.linkedin.com/jobs/view/business-dev...
# 8   https://in.linkedin.com/jobs/view/business-dev...
# 9   https://in.linkedin.com/jobs/view/business-dev...
# 10  https://in.linkedin.com/jobs/view/business-dev...
# 11  https://in.linkedin.com/jobs/view/business-dev...
# 12  https://in.linkedin.com/jobs/view/business-dev...
# 13  https://in.linkedin.com/jobs/view/area-busines...
# 14  https://in.linkedin.com/jobs/view/business-dev...
# 15  https://in.linkedin.com/jobs/view/business-dev...
# 16  https://in.linkedin.com/jobs/view/business-dev...
# 17  https://in.linkedin.com/jobs/view/senior-busin...
# 18  https://in.linkedin.com/jobs/view/business-dev...
# 19  https://in.linkedin.com/jobs/view/business-dev...
# 20  https://in.linkedin.com/jobs/view/sales-adviso...
# 21  https://in.linkedin.com/jobs/view/business-ana...
# 22  https://in.linkedin.com/jobs/view/analyst-busi...
# 23  https://in.linkedin.com/jobs/view/business-dev...
# 24  https://in.linkedin.com/jobs/view/business-dev...

# %%
def job_title_filter(x, user_input_job_title):
    
    s = [i.lower() for i in user_input_job_title]
    suggestion = []
    for i in s:
        suggestion.extend(i.split())

    s = x.split()
    a = [i.lower() for i in s]
    
    intersection = list(set(suggestion).intersection(set(a)))
    return x if len(intersection)>1 else np.nan

# %%
df['Job Title'] = df['Job Title'].apply(lambda x: job_title_filter(x, user_input_job_title))
df=df.dropna()
df.reset_index(drop=True, inplace=True)
df
# Out:
#                    Company Name  \
# 0                    MakeMyTrip
# 1                     Unacademy
# 2                    Freshworks
# 3   Pidilite Industries Limited
# 4                    Freshworks
# 5                     Unacademy
# 6                     Unacademy
# 7                       Ferrero
# 8                     Unacademy
# 9                     Unacademy
# 10         Aditya Birla Capital
# 11         Aditya Birla Capital
# 12         Aditya Birla Capital
# 13                   Freshworks
# 14                      Schbang
# 15                       Amazon
# 16                   Freshworks
# 17                   Freshworks
#
#                                             Job Title  \
# 0               Business Development Manager - Nashik
# 1                      Business Development Executive
# 2                 Business Development Manager - MENA
# 3                      Business Development Executive
# 4                      Business Development Executive
# 5                      Business Development Executive
# 6                      Business Development Executive
# 7                   Business Development Officer Pune
# 8                      Business Development Executive
# 9                      Business Development Executive
# 10                 Business Development Manager (BDM)
# 11                 Business Development Manager (BDM)
# 12                 Business Development Manager (BDM)
# 13          Senior Business Development Manager - ANZ
# 14                     Business Development Executive
# 15  Business Development Manager-GlobalSellingIN, ...
# 16                  Business Development Manager - NA
# 17  Business Development Executive - Inside sales ...
#
#                              Location  \
# 0          Nashik, Maharashtra, India
# 1         Bengaluru, Karnataka, India
# 2         Bengaluru, Karnataka, India
# 3           Muzaffarpur, Bihar, India
# 4          Chennai, Tamil Nadu, India
# 5   Bangalore Urban, Karnataka, India
# 6         Bengaluru, Karnataka, India
# 7            Pune, Maharashtra, India
# 8                        Delhi, India
# 9                        Delhi, India
# 10          Ahmedabad, Gujarat, India
# 11         Chennai, Tamil Nadu, India
# 12             Cuttack, Odisha, India
# 13        Bengaluru, Karnataka, India
# 14         Mumbai, Maharashtra, India
# 15        Bengaluru, Karnataka, India
# 16         Chennai, Tamil Nadu, India
# 17         Chennai, Tamil Nadu, India
#
#                                           Website URL
# 0   https://in.linkedin.com/jobs/view/business-dev...
# 1   https://in.linkedin.com/jobs/view/business-dev...
# 2   https://in.linkedin.com/jobs/view/business-dev...
# 3   https://in.linkedin.com/jobs/view/business-dev...
# 4   https://in.linkedin.com/jobs/view/business-dev...
# 5   https://in.linkedin.com/jobs/view/business-dev...
# 6   https://in.linkedin.com/jobs/view/business-dev...
# 7   https://in.linkedin.com/jobs/view/business-dev...
# 8   https://in.linkedin.com/jobs/view/business-dev...
# 9   https://in.linkedin.com/jobs/view/business-dev...
# 10  https://in.linkedin.com/jobs/view/business-dev...
# 11  https://in.linkedin.com/jobs/view/business-dev...
# 12  https://in.linkedin.com/jobs/view/business-dev...
# 13  https://in.linkedin.com/jobs/view/senior-busin...
# 14  https://in.linkedin.com/jobs/view/business-dev...
# 15  https://in.linkedin.com/jobs/view/business-dev...
# 16  https://in.linkedin.com/jobs/view/business-dev...
# 17  https://in.linkedin.com/jobs/view/business-dev...

# %%
df=df.iloc[:10,:]
df
# Out:
#                   Company Name                              Job Title  \
# 0                   MakeMyTrip  Business Development Manager - Nashik
# 1                    Unacademy         Business Development Executive
# 2                   Freshworks    Business Development Manager - MENA
# 3  Pidilite Industries Limited         Business Development Executive
# 4                   Freshworks         Business Development Executive
# 5                    Unacademy         Business Development Executive
# 6                    Unacademy         Business Development Executive
# 7                      Ferrero      Business Development Officer Pune
# 8                    Unacademy         Business Development Executive
# 9                    Unacademy         Business Development Executive
#
#                             Location  \
# 0         Nashik, Maharashtra, India
# 1        Bengaluru, Karnataka, India
# 2        Bengaluru, Karnataka, India
# 3          Muzaffarpur, Bihar, India
# 4         Chennai, Tamil Nadu, India
# 5  Bangalore Urban, Karnataka, India
# 6        Bengaluru, Karnataka, India
# 7           Pune, Maharashtra, India
# 8                       Delhi, India
# 9                       Delhi, India
#
#                                          Website URL
# 0  https://in.linkedin.com/jobs/view/business-dev...
# 1  https://in.linkedin.com/jobs/view/business-dev...
# 2  https://in.linkedin.com/jobs/view/business-dev...
# 3  https://in.linkedin.com/jobs/view/business-dev...
# 4  https://in.linkedin.com/jobs/view/business-dev...
# 5  https://in.linkedin.com/jobs/view/business-dev...
# 6  https://in.linkedin.com/jobs/view/business-dev...
# 7  https://in.linkedin.com/jobs/view/business-dev...
# 8  https://in.linkedin.com/jobs/view/business-dev...
# 9  https://in.linkedin.com/jobs/view/business-dev...

# %%
def description(link):

    driver.get(link)
    time.sleep(3)

    driver.find_element(by=By.CSS_SELECTOR, value='button[data-tracking-control-name="public_jobs_show-more-html-btn"]').click()
    time.sleep(2)

    description = driver.find_elements(by=By.CSS_SELECTOR, value='div[class="show-more-less-html__markup relative overflow-hidden"]')
    driver.implicitly_wait(4)
    
    for j in description:
        return j.text

# %%
website_url = df['Website URL'].tolist()

job_description = []

for i in website_url:
    data = description(i)
    if data is not None and len(data.strip()) > 0:
        job_description.append(data)
    else:
        job_description.append('Description Not Available')

# %%
df['Job Description'] = pd.DataFrame(job_description, columns=['Description'])
df
# Out:
#                   Company Name                              Job Title  \
# 0                   MakeMyTrip  Business Development Manager - Nashik
# 1                    Unacademy         Business Development Executive
# 2                   Freshworks    Business Development Manager - MENA
# 3  Pidilite Industries Limited         Business Development Executive
# 4                   Freshworks         Business Development Executive
# 5                    Unacademy         Business Development Executive
# 6                    Unacademy         Business Development Executive
# 7                      Ferrero      Business Development Officer Pune
# 8                    Unacademy         Business Development Executive
# 9                    Unacademy         Business Development Executive
#
#                             Location  \
# 0         Nashik, Maharashtra, India
# 1        Bengaluru, Karnataka, India
# 2        Bengaluru, Karnataka, India
# 3          Muzaffarpur, Bihar, India
# 4         Chennai, Tamil Nadu, India
# 5  Bangalore Urban, Karnataka, India
# 6        Bengaluru, Karnataka, India
# 7           Pune, Maharashtra, India
# 8                       Delhi, India
# 9                       Delhi, India
#
#                                          Website URL  \
# 0  https://in.linkedin.com/jobs/view/business-dev...
# 1  https://in.linkedin.com/jobs/view/business-dev...
# 2  https://in.linkedin.com/jobs/view/business-dev...
# 3  https://in.linkedin.com/jobs/view/business-dev...
# 4  https://in.linkedin.com/jobs/view/business-dev...
# 5  https://in.linkedin.com/jobs/view/business-dev...
# 6  https://in.linkedin.com/jobs/view/business-dev...
# 7  https://in.linkedin.com/jobs/view/business-dev...
# 8  https://in.linkedin.com/jobs/view/business-dev...
# 9  https://in.linkedin.com/jobs/view/business-dev...
#
#                                      Job Description
# 0  About the job\n\nFunction : Supply - Independe...
# 1  6 days working - WFO\n\nJob Summary:\n\nBusine...
# 2  Company Description\n\nAbout Freshworks\n\nFre...
# 3  Hi\nPidilite hiring for Business Development E...
# 4  Company Description\n\nAbout Freshworks\n\nFre...
# 5  6 days working - WFO\nLocation - Noida & Banga...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
l = len(df['Company Name'])
for i in range(0,l):
    print(f"Company Name : {df.iloc[i,0]}")
    print(f"Job Title    : {df.iloc[i,1]}")
    print(f"Location     : {df.iloc[i,2]}")
    print(f"Website URL  : {df.iloc[i,3]}")
    print(f"Description  : {df.iloc[i,4]}")
# Out:
# Company Name : MakeMyTrip
# Job Title    : Business Development Manager - Nashik
# Location     : Nashik, Maharashtra, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-manager-nashik-at-makemytrip-3841514822?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=LlB1mnPpq58jris2kkEMEA%3D%3D&position=1&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : About the job
#
# Function : Supply - Independent Domestic Hotel
# Role : Business Development Manager
# Level : Senior Executive/Assistant Manager
# Location : Nashik
#
# Role Overview:
#
# The incumbent will be responsible for connecting and engaging with premium independent hotels. He/She will be responsible for end to end key account management and driving sustainable performance of the region. The role involves travel to different cities in the portfolio and providing expertise, metrics, analysis and recommendations based on the industry's best practices to the hotel partners.
#
# Know the Function:
#
# The Independent Hotels team is part of the Domestic Hotel Supply Function and this team manages supply from Independent hotels based across India. and has about 60k+ Hotels contracted on our platforms
#
# Key Learnings in this role:
#
# Managing large scale hotel accounts
# Forming strategic partnerships with hotel partners
# Exposure to engage and learn from leading industry stalwarts
# Build remote working relationships
# Gain Contracting and Financial acumen
#
# Skills you will bring to the table:
#
# 1. Relationship and Account Management :
#
# The Person will be responsible for connecting and engaging with independent hotels
# End to end account management and driving sustainable performance of the region
# The role involves travel to different cities in the portfolio and providing expertise, metrics, analysis and recommendations based on the industry's best practices to the hotel partners
#
# 2. Portfolio Management and Driving Growth :
#
# Grow net revenue in the market by producing business plans to achieve revenue goals, ensuring inventory levels exceed demand throughout the market, ensuring rate competitiveness across multiple available platforms
#
# 3. Data Analysis and Reporting:
#
# Establish and maintain supplier relationships, train partner hotels on our extranet and the wholesale business, review monthly production reports and provide feedback to top producing hotels, plan and execute market site visits
# Building MIS & market intelligence reports, preparing geography wise and service wise sales plans and achieving them. Sharing insights on market and industry with the clients and internal stake holders
#
# 4. Negotiating:
#
# Networking, Deal initiating, negotiation & closing deal with the clients.
# Strategize in order to market the hotel in a better way. It helps hotel partners to serve the needs of their customers and at the same time grow their businesses
#
# Tools that will be used:
#
# MS Excel • MS Power-point
#
# What are we looking for in you?
#
# Relevant Experience:
#
# Preferred candidates having past work experience in sales/Travel Trade/ Key Account management/ Contracting/B2B Sales.
# Experience in handling multiple accounts as a partner is preferred.
#
# Personality:
#
# Good at numbers and data analysis
# Strong communication skills
# Team player
# Flair for Travel are also pre-requisite for the job profile
# Strategic thinking
# High on analytical and problem solving skills
# Analytics bend of mind and Good Presentation skills
#
# What's in it for you?
#
# Our focus has always been on delivering value to our customers and employees alike and we truly believe that Happy Employees Make Happy Customers. If fast pace work environment and learning opportunities excite you, then come and join us.
# Company Name : Unacademy
# Job Title    : Business Development Executive
# Location     : Bengaluru, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3821021443?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=YrHr7ImE24xi5bJlHCrhCw%3D%3D&position=3&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : 6 days working - WFO
#
# Job Summary:
#
# Business development executives are responsible for driving company sales by sourcing new clients, and by convincing existing clients to purchase added offerings. As such, business development executives play an integral role in companies' longevity.
#
# We are looking for a resilient, empathic business development executive to contribute to the growth of our company. Business development executives are responsible for finding and retaining clients, encouraging extant clients to purchase added products or features, and remaining abreast of changes in consumption. You will also be required to build capacity in staff through regular training and mentorship. To be successful as a business development executive, you should attend networking events with the intention of attracting and retaining clientele. Ultimately, an outstanding business development executive will keep a close eye on clients' feedback to ensure that our products and services always exceed expectations.
#
# Responsibilities:
#
# ● Familiarizing yourself with all products and services offered by our company.
# ● Procuring new clients through direct contact, word-of-mouth, and collaboration with the marketing department.
# ● Attending networking activities to research and connect with prospective clients.
# ● Maintaining meaningful relationships with existing clients to ensure that they are retained.
# ● Suggesting upgrades or added products and services that may be of interest to clients.
# ● Crafting business proposals and contracts to draw in more revenue from clients.
# ● Negotiating with clients to secure the most attractive prices.
# ● Equipping staff with the technical and social skills needed to enhance sales.
# ● Reviewing clients' feedback and implementing necessary changes.
# ● Remaining in tune with trends in consumption to ensure that our offerings remain relevant.
#
# Requirements:
#
# ● Degree in marketing, business administration, or similar.
# ● Extensive sales experience.
# ● Intuitive and insightful, particularly regarding human behavior.
# ● Ability to generate revenue by identifying pain points and suggesting suitable products or services.
# ● Professional yet affable disposition.
# ● Neat, well-groomed appearance.
# ● Great networking skills.
# ● Excellent written and verbal communication.
# ● Resourceful, with outstanding research skills.
# ● Emboldened by challenges.
# Company Name : Freshworks
# Job Title    : Business Development Manager - MENA
# Location     : Bengaluru, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-manager-mena-at-freshworks-3825476563?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=2RGD%2B1cE6k%2FhHYa8aleuvQ%3D%3D&position=5&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Company Description
#
# About Freshworks
#
# Freshworks makes it fast and easy for businesses to delight their customers and employees. We do this by taking a fresh approach to building and delivering software that is affordable, quick to implement, and designed for the end user. More than 50,000 companies -- from startups to public companies -- around the world use Freshworks software-as-a-service to enable a better customer experience ]CRM) and employee experience (ITSM, HRSM).
#
# Headquartered in San Mateo, California, Freshworks has a dedicated team operating from 13 global locations to serve 50,000+ customers including Bridgestone, Chargebee, DeliveryHero, ITV, Klarna, Multichoice, OfficeMax, TaylorMade and Vice Media.
#
# Freshworks transforms the way world-class organizations collaborate with customers and co-workers. The suite includes Freshdesk (omni-channel customer support), Freshsales (sales automation), Freshmarketer (marketing automation), Freshservice (IT service desk), Freshteam (HR management system).
#
# Freshworks has received numerous accolades including 2019 Startup of the Year form Economic Times, #16 ranking on the Forbes’ Cloud 100 list and #22 on the Battery Ventures/Glassdoor Best Places to Work in 2020. Our suite of products has also been recognized by analysts including the Gartner Magic Quadrants for CRM Customer Engagement, IT Service Management and Sales Force Automation.
#
# While Freshworks has had incredible organic growth over the last few years, the company also has made targeted acquisitions that add critical capabilities to the portfolio including Natural Language Processing, Chatbots, Machine Learning, Social and Messaging Transformation. Freshworks has raised over $400 million in capital and is funded by Accel, CapitalG, Sequoia Capital and Tiger Global Management. More information is available at www.Freshworks.com.
#
# At Freshworks, we are creating a global workplace that enables everyone to find their true potential, purpose and passion, irrespective of their background, gender, race, sexual orientation, religion or ethnicity. We are committed to providing equal opportunity for all and believe that diversity in the workplace creates a more vibrant, richer work environment that advances the goals of our employees, our communities and our business.
#
# Job Description
#
# Overview -
#
# We are currently looking to hire high-potential BDMs. This position is an integral part of our sales engine. BDMs are focused on the front end of the sales cycle and are the face of Freshworks. The BDM team is responsible for identifying opportunities and generating a sales pipeline. This role is based out of Bangalore.
#
# Responsibilities (What You'll Be Expected To Do) -
#
# Generate qualified opportunities for the company by rigorously prospecting and researching in the assigned region/market.
# Do rigorous research on assigned accounts, and build an effective sales pipeline.
# Strike and initiate conversations with high-profile personas of companies you are prospecting.
# Be the face of Freshworks and pitch the company and our products to the prospects.
# Come up with creative emails and campaigns to draw the attention of prospects.
#
# Qualifications
#
# Requirements (What we look for in candidates):
#
# Must-haves -
#
# 4 to 7 years of work experience in any customer-facing sales/BD role
# Willingness to work in the ANZ shift (4 Am to 1Pm)
# Willingness to work in-office for 5 days a week
# Clear, concise, and effective written and oral communication skills.
# Empathy towards customers and understanding their needs.
# Interest, curiosity, and openness to learning new technologies.
# Good interpersonal skills and ability to collaborate with internal stakeholders as well as end customers.
# Learning mindset and the right attitude that will help you thrive and adapt in a fast-paced, performance-driven environment.
# Ability to handle rejections and stay focused and driven.
# Ability to multi-task and manage your tasks effectively.
# Ability to ask the right questions and qualify a customer's needs
# Ability to ask open-ended questions and understand the customer's pain points
# Ability to do a PowerPoint presentation and explain the capabilities of our products to customers
# understand the Regional nuances of designated market
# Experience in cold calling
# Understanding the Sales metrics and numbers
# Capture Minutes and Meetings and update CRM Meticulously.
#
# Good to have -
#
# Prior work experience in B2B SaaS product companies in domains relevant to Freshworks' suite of products.
# Prior exposure to tools like LinkedIn Sales Navigator, DiscoverOrg, ZoomInfo, etc.
# The proven track record of consistency in overachieving targets.
#
# Additional Information
#
# All your information will be kept confidential according to EEO guidelines.
#
# At Freshworks, we are creating a global workplace that enables everyone to find their true potential, purpose, and passion irrespective of their background, gender, race, sexual orientation, religion and ethnicity. We are committed to providing equal opportunity for all and believe that diversity in the workplace creates a more vibrant, richer work environment that advances the goals of our employees, communities and the business.
# Company Name : Pidilite Industries Limited
# Job Title    : Business Development Executive
# Location     : Muzaffarpur, Bihar, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-executive-at-pidilite-industries-limited-3840007419?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=IOYVh30RXAQwZnfimsFayA%3D%3D&position=7&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Hi
# Pidilite hiring for Business Development Executive
# Designation : Business Development Executive
# Location : Muzaffarpur ( Bihar )
# Exp : Min 3 years to 6 years on roll exp in Channel and Project Sales from Paint , Cement , Construction Chemical , Water Proof Chemical , Adhesive ,Tiles ,Ceramics
# JOB DESCRIPTION:
#
# Please find below JD for your reference.
# Promotional Activity to be done Through Team and own
# Key Accounts Tracking and Solutions Selling
# Projects Visits and LMS conversion
# RTG User Connect and Banking
# Focus Products Sales and Marketing
# Market and Products development
# Education : B.TECH / Dip ( Civil ) Preferred
# Communication : Good communication
# Age : Up to 32
# Interested please share your resume to ots281@pidilite.com
#
# Regards
# Sabita Roy
# Company Name : Freshworks
# Job Title    : Business Development Executive
# Location     : Chennai, Tamil Nadu, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-executive-at-freshworks-3825477572?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=I4Ia64vLHhiaseg068X%2B7g%3D%3D&position=8&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : Company Description
#
# About Freshworks
#
# Freshworks makes it fast and easy for businesses to delight their customers and employees. We do this by taking a fresh approach to building and delivering software that is affordable, quick to implement, and designed for the end user. Headquartered in San Mateo, California, Freshworks has a global team operating from 13 global locations to serve more than 65,000 companies -- from startups to public companies – that rely on Freshworks software-as-a-service to enable a better customer experience (CRM, CX) and employee experience (ITSM).
#
# Freshworks’ cloud-based software suite includes Freshdesk (omni-channel customer support), Freshsales (sales automation), Freshmarketer (marketing automation), Freshservice (IT service desk), Freshchat (AI-powered bots), supported by Neo, our underlying platform of shared services.
#
# Freshworks is featured in global national press including CNBC, Forbes, Fortune, Bloomberg and has been a BuiltIn Best Place to work in San Francisco and Denver for the last 3 years. Our customer ratings have earned Freshworks products TrustRadius Top Rated Software ratings and G2 Best of Awards for Best Feature Set, Best Value for the Price and Best Relationship.
#
# Job Description
#
# Overview:
#
# We are looking to hire smart and passionate folks for our inside sales team. The inside sales team are responsible for engaging with prospects and driving sales in the SMB segment. They understand the needs and requirements and collaborate with internal teams to help ensure a smooth sales process. This role is based out of Chennai.
#
# Responsibilities (What you'll be expected to do):
#
# Be an enthusiastic person with Go-getter mindset to generate outbound prospects(with calls, emails & LinkedIn) and qualify them through continuous follow-ups and lead them to closure based on their requirement(end to end sales process).
# Own individual targets and work towards onboarding new customers .
# Generate revenue to hit individual targets & support to achieve team Target
# Collaborate with internal teams and represent Freshworks to the customer to solve their business requirements & queries.
#
# Qualifications
#
# Minimum graduate degree is mandatory
#
# 1- 4 years of work experience in any customer-facing role with Cold calling experience is a mandatory.
# Clear, concise, and effective written and oral communication skills.
# Empathy towards customers and understanding their needs/requirements.
# Interest, curiosity, and openness to learning new products & bring up new ideas.
# Good interpersonal skills and ability to collaborate with internal stakeholders(teams) as well as end customers.
# Learning mindset and the right attitude that will help you thrive and adapt in a fast-paced, performance-driven environment.
# Flexibility in working in different shifts/regions. This is absolutely mandatory because you will be expected to work in a specific shift for a minimum of two years.
#
# Additional Information
#
# All your information will be kept confidential according to EEO guidelines.
#
# At Freshworks, we are creating a global workplace that enables everyone to find their true potential, purpose, and passion irrespective of their background, gender, race, sexual orientation, religion and ethnicity. We are committed to providing equal opportunity for all and believe that diversity in the workplace creates a more vibrant, richer work environment that advances the goals of our employees, communities and the business.
# Company Name : Unacademy
# Job Title    : Business Development Executive
# Location     : Bangalore Urban, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3835910631?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=3Dp9K%2Btg19WZQ5W5JJdMjg%3D%3D&position=9&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : 6 days working - WFO
# Location - Noida & Bangalore
#
# Job Summary:
#
# Business development executives are responsible for driving company sales by sourcing new clients, and by convincing existing clients to purchase added offerings. As such, business development executives play an integral role in companies' longevity.
#
# We are looking for a resilient, empathic business development executive to contribute to the growth of our company. Business development executives are responsible for finding and retaining clients, encouraging extant clients to purchase added products or features, and remaining abreast of changes in consumption. You will also be required to build capacity in staff through regular training and mentorship. To be successful as a business development executive, you should attend networking events with the intention of attracting and retaining clientele. Ultimately, an outstanding business development executive will keep a close eye on clients' feedback to ensure that our products and services always exceed expectations.
#
# Responsibilities:
#
# ● Familiarizing yourself with all products and services offered by our company.
# ● Procuring new clients through direct contact, word-of-mouth, and collaboration with the marketing department.
# ● Attending networking activities to research and connect with prospective clients.
# ● Maintaining meaningful relationships with existing clients to ensure that they are retained.
# ● Suggesting upgrades or added products and services that may be of interest to clients.
# ● Crafting business proposals and contracts to draw in more revenue from clients.
# ● Negotiating with clients to secure the most attractive prices.
# ● Equipping staff with the technical and social skills needed to enhance sales.
# ● Reviewing clients' feedback and implementing necessary changes.
# ● Remaining in tune with trends in consumption to ensure that our offerings remain relevant.
#
# Requirements:
#
# ● Degree in marketing, business administration, or similar.
# ● Extensive sales experience.
# ● Intuitive and insightful, particularly regarding human behavior.
# ● Ability to generate revenue by identifying pain points and suggesting suitable products or services.
# ● Professional yet affable disposition.
# ● Neat, well-groomed appearance.
# ● Great networking skills.
# ● Excellent written and verbal communication.
# ● Resourceful, with outstanding research skills.
# ● Emboldened by challenges.
# Company Name : Unacademy
# Job Title    : Business Development Executive
# Location     : Bengaluru, Karnataka, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3835914425?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=joD8k1jkVPcAgHtYlrY8Xw%3D%3D&position=10&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : nan
# Company Name : Ferrero
# Job Title    : Business Development Officer Pune
# Location     : Pune, Maharashtra, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-officer-pune-at-ferrero-3841601092?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=TRR6NkNqCsIm8TbLoKJ8zQ%3D%3D&position=11&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : nan
# Company Name : Unacademy
# Job Title    : Business Development Executive
# Location     : Delhi, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3837573106?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=9JyusVqgPVr0%2F%2Fv2w7wssQ%3D%3D&position=12&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : nan
# Company Name : Unacademy
# Job Title    : Business Development Executive
# Location     : Delhi, India
# Website URL  : https://in.linkedin.com/jobs/view/business-development-executive-at-unacademy-3840102403?refId=kzTN8UPBtCaKicQdE7ASPA%3D%3D&trackingId=S77xg%2B%2FDKzNglVvHoOM2%2FA%3D%3D&position=13&pageNum=0&trk=public_jobs_jserp-result_search-card
# Description  : nan
